# %% [markdown]
# # IMPORTION IMPORTANT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # IMPORTING DATA SET

# %%
df=pd.read_csv("baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# # ABOUT THE DATASET:-
#     *Project Description
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of
# wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that
# will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
#     *Input features-
#
# 1. W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took
#     the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# 2. R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#
# 3. AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# 4. H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#
# 5. 2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 6. 3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# 7. HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# 8. BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# 9. SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#
# 10. SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# 11. RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#
# 12. ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
# 13. ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# 14. CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#
# 15. SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#
# 16. SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# 17. E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# # START EXPLORATORY DATA ANALAYSIS

# %%
print("NUMBER OF ROWS IN THE DATASET ",df.shape[0])
print("NUMBER OF COLUMNS IN DATASET ",df.shape[1])
# Out:
# NUMBER OF ROWS IN THE DATASET  30
# NUMBER OF COLUMNS IN DATASET  17

# %% [markdown]
# # IDENTIFIED THE DATASET TYPE:-

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# OBSERVATION:-
#
#     *THE DATATYPE OF DATASET IS INTEGER EXCEPT ERA(EARNED RUN AVERAGE) WHICH IS IN FLOAT

# %% [markdown]
# # CHECK NULL, DUPLICATE AND UNIQUE  VALUES IN DATASET

# %%
df.isnull().any()
# Out:
# W      False
# R      False
# AB     False
# H      False
# 2B     False
# 3B     False
# HR     False
# BB     False
# SO     False
# SB     False
# RA     False
# ER     False
# ERA    False
# CG     False
# SHO    False
# SV     False
# E      False
# dtype: bool

# %% [markdown]
# THERE IS NO NULL VALUE IN A DATASET

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %% [markdown]
# THERE IS NO DULPICATE VALUE IN DATASET

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# THER IS NUMBER OF UNIQUE VALUE IN DATASET

# %%
plt.figure(figsize=(9,7))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# AS WE SEEN IN THE GRAPH THEIR IS NO NULL VALUE IN THE GRAPH

# %% [markdown]
# # DESCRIBE THE DATASET

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# AS WE SEEN IN ABOVE TABLE THEIR IS NO NEGATIVE VALUES, ALL COLUMNS HAVE 30 VALUE COUNTS, THE MEAN IS VARIES COLUMNS WISE,SOME COLUMNS SHOW HIGH VALUE AND SOME COLUMNS SHOW LOW VALUES IN THE DATASET

# %% [markdown]
# # DATA VISUALIZATION

# %%
for i in df.columns:
    plt.figure(figsize=(5,4))
    sns.histplot(df[i],color="red")
    plt.xlabel(i,fontsize=18,fontweight="bold")
    plt.ylabel("COUNT",fontsize=18,fontweight="bold")
    plt.xticks(fontweight="bold")
    plt.yticks(fontweight="bold")

# %%
for i in df.columns:
    plt.figure(figsize=(5,4))
    sns.distplot(df[i],color="orange")
    plt.xticks(fontweight="bold")
    plt.yticks(fontweight="bold")
    plt.xlabel(i,fontweight="bold",fontsize=18)
    plt.ylabel("density",fontweight="bold",fontsize=18)

# %% [markdown]
# OBSERVATION:-
#
#     *ALL MOST ALL FEATURES HAVE NORMAL DENSITY EXCEPT R,SO,CG AND E

# %% [markdown]
# # LET'S CHECK SOME OUTLIEARS BY BOX PLOT

# %%
for i in df.columns:
    plt.figure(figsize=(8,5))
    sns.boxplot(df[i])
    plt.xticks(fontweight="bold")
    plt.xlabel(i,fontweight='bold',fontsize=18)

# %% [markdown]
# AS we seen most of the columns do not have outliears except R,ERA,SHO,SV,E

# %% [markdown]
# # BIVARIATE ANALAYSIS

# %%
for i in df.columns:
    plt.figure(figsize=(5,4))
    sns.regplot(df["W"],df[i])
    plt.xlabel(i,fontsize=18,fontweight="bold")
    plt.ylabel("w",fontsize=18,fontweight="bold")
    plt.xticks(fontweight="bold")
    plt.yticks(fontweight="bold")

# %% [markdown]
# AS WE SEEN ONLY SOME COLUMNS HAVE GOOD RELATION WITH WIN THE FEATURES ARE:- ERA,ER,RA EXCEPT THESE ALL OTHERS ARE HIGHLY SCATTER

# %%
for i in df.columns:
    plt.figure(figsize=(5,4))
    sns.lineplot(df["W"],df[i])

# %% [markdown]
# # MULTIVARIATE ANALAYSIS

# %%
sns.pairplot(df)

# %% [markdown]
# # NOW LETS UNDERSTAND CORRELATION

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
plt.figure(figsize=(17,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(17,5))
df.corr()["W"].drop(["W"]).sort_values(ascending=False).plot(kind="bar",color="c")
# Out:
# <AxesSubplot:>

# %% [markdown]
# OBSERVATION:-
#
#     *AS WE SEEN IN FIGURE MOSTLY DATA IN POSITIVE CORRECLATION WITH WIN EXCEPT ER,RA,ERA. WHICH ARE HIGHLY NEGATIVE CORRELATIED WITH WIN
#
#     *SV,BB,SHO ARE HIGHLY POSITIVE CORRERALITED WITH WIN HAVING VALUE 0.6,0.4
#
#     *ER RA ERA SHOW HIGHEST CORRELATION VALE 0.8 BUT IN NEGATIVE

# %% [markdown]
# # REMOVING OUTLIERS

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1
for i in df.columns:
    if plotnumber<=40:
        ax=plt.subplot(10,4,plotnumber)
        sns.boxplot(df[i],color='gold')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# AS WE SEEN IN FIGURE THERE IS SOME OUTLIERS. R,ERA,SHQ,SV,E CLOUMNS HAVE OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# CHECK DATA LOSS PERCENTAGE

# %%
df.shape
# Out:
# (30, 17)

# %%
df_new.shape
# Out:
# (29, 17)

# %%
data_loss=((30-29)/30)*100

# %%
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# PERCENTAGE OF DATA LOSS IS BELOW 10%

# %% [markdown]
# # SEPRATING THE COLUMNS INTO FEATURES AND TARGETS

# %%
df=df_new

# %%
x=df.drop("W",axis=1)

# %%
y=df["W"]

# %% [markdown]
# # SCALING USING MINMAX SCALER

# %%
from sklearn.preprocessing import MinMaxScaler
mms= MinMaxScaler()

# %%
X=pd.DataFrame(mms.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.790576  0.719697  0.905759  0.955224  0.805556  0.300000  0.041667
# 1  0.643979  0.310606  0.130890  0.611940  0.861111  0.430769  0.333333
# 2  0.502618  0.204545  0.371728  1.000000  0.444444  0.315385  0.822917
# 3  0.256545  0.560606  0.298429  0.358209  0.388889  0.276923  0.151042
# 4  0.607330  0.833333  1.000000  0.791045  1.000000  0.392308  0.416667
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0  0.000000  0.666667  0.363636  0.383178  0.376190  0.181818  0.235294
# 1  0.533945  0.288889  0.548589  0.545171  0.538095  0.181818  0.470588
# 2  0.337615  0.466667  0.360502  0.330218  0.347619  1.000000  0.352941
# 3  0.473394  0.266667  0.551724  0.514019  0.495238  0.636364  0.294118
# 4  0.524771  0.433333  0.871473  0.834891  0.809524  0.636364  0.470588
#
#          SV         E
# 0  0.823529  0.254902
# 1  0.500000  0.215686
# 2  0.294118  0.078431
# 3  0.264706  0.509804
# 4  0.205882  0.215686

# %% [markdown]
# # MACHINE LEARNING MODEL

# %% [markdown]
# 1.) LET ME CHECK BEST RANDOM MODEL FOR TESTING

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
lin_reg=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.33,random_state=i)
    lin_reg.fit(x_train,y_train)
    pred_train=lin_reg.predict(x_train)
    pred_test=lin_reg.predict(x_test)
    print(f'At random state{i}, The training accuracy is : {r2_score(y_train,pred_train)}')
    print(f'At random state{i}, The test accuracy is : {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is : 0.984551297917736
# At random state0, The test accuracy is : 0.5747957529294954
#
#
# At random state1, The training accuracy is : 0.9971615048470072
# At random state1, The test accuracy is : 0.23303547621997933
#
#
# At random state2, The training accuracy is : 0.976772549963098
# At random state2, The test accuracy is : -0.053475302620639376
#
#
# At random state3, The training accuracy is : 0.9690350212339552
# At random state3, The test accuracy is : 0.49275864285876403
#
#
# At random state4, The training accuracy is : 0.988049007612332
# At random state4, The test accuracy is : -0.40261738401456126
#
#
# At random state5, The training accuracy is : 0.9779981338233059
# At random state5, The test accuracy is : 0.31400739763759467
#
#
# At random state6, The training accuracy is : 0.9982510533905158
# At random state6, The test accuracy is : -0.7585135826798122
#
#
# At random state7, The training accuracy is : 0.9947699471400965
# At random state7, The test accuracy is : -1.4797511562242058
#
#
# At random state8, The training accuracy is : 0.9910290075345639
# At random state8, The test accuracy is : 0.5690502336813744
#
#
# At random state9, The training accuracy is : 0.9972038548471754
# At random state9, The test accuracy is : -1.0859151731096315
#
#
# At random state10, The training accuracy is : 0.9975281883201232
# At random state10, The test accuracy is : -0.769151653293805
#
#
# At random state11, The training accuracy is : 0.9859655191996273
# At random state11, The test accuracy is : -0.17212831646613824
#
#
# At random state12, The training accuracy is : 0.9862828291496861
# At random state12, The test accuracy is : 0.7311671015677299
#
#
# At random state13, The training accuracy is : 0.9809731478347483
# At random state13, The test accuracy is : 0.568365532911224
#
#
# At random state14, The training accuracy is : 0.9898601989686684
# At random state14, The test accuracy is : 0.26685062304858165
#
#
# At random state15, The training accuracy is : 0.9887320409435275
# At random state15, The test accuracy is : 0.10632348525382951
#
#
# At random state16, The training accuracy is : 0.9976338723112856
# At random state16, The test accuracy is : -0.18147028632680895
#
#
# At random state17, The training accuracy is : 0.9793910484838872
# At random state17, The test accuracy is : -0.07667620034900358
#
#
# At random state18, The training accuracy is : 0.9914895739600896
# At random state18, The test accuracy is : -0.5132216135542138
#
#
# At random state19, The training accuracy is : 0.9844307976276988
# At random state19, The test accuracy is : -0.07870336302940006
#
#
# At random state20, The training accuracy is : 0.9914867001089177
# At random state20, The test accuracy is : 0.14947703477637653
#
#
# At random state21, The training accuracy is : 0.9999185567896232
# At random state21, The test accuracy is : -2.576288733812356
#
#
# At random state22, The training accuracy is : 0.9506826633094633
# At random state22, The test accuracy is : 0.8402333261792634
#
#
# At random state23, The training accuracy is : 0.9838523404769249
# At random state23, The test accuracy is : 0.19112309069350863
#
#
# At random state24, The training accuracy is : 0.9950138883101461
# At random state24, The test accuracy is : -1.2350127470738683
#
#
# At random state25, The training accuracy is : 0.9800131494015643
# At random state25, The test accuracy is : -1.3976487305146756
#
#
# At random state26, The training accuracy is : 0.9776105526776355
# At random state26, The test accuracy is : 0.6057286704747508
#
#
# At random state27, The training accuracy is : 0.9887457466255212
# At random state27, The test accuracy is : 0.5339397775885861
#
#
# At random state28, The training accuracy is : 0.9945860261294592
# At random state28, The test accuracy is : -0.02115894883928071
#
#
# At random state29, The training accuracy is : 0.9782118560827402
# At random state29, The test accuracy is : -1.8841431953783347
#
#
# At random state30, The training accuracy is : 0.9698019133902992
# At random state30, The test accuracy is : -0.08480698589654279
#
#
# At random state31, The training accuracy is : 0.9868002434176977
# At random state31, The test accuracy is : 0.21691707005215288
#
#
# At random state32, The training accuracy is : 0.9815012457270683
# At random state32, The test accuracy is : 0.48194757821984524
#
#
# At random state33, The training accuracy is : 0.9754970345373913
# At random state33, The test accuracy is : 0.1871654264031014
#
#
# At random state34, The training accuracy is : 0.9969272760774426
# At random state34, The test accuracy is : -1.7042302884305824
#
#
# At random state35, The training accuracy is : 0.9860114499407023
# At random state35, The test accuracy is : 0.6795729618428268
#
#
# At random state36, The training accuracy is : 0.987111106252976
# At random state36, The test accuracy is : 0.09769957816206465
#
#
# At random state37, The training accuracy is : 0.9983852734766895
# At random state37, The test accuracy is : 0.23693090178612852
#
#
# At random state38, The training accuracy is : 0.9948546630901222
# At random state38, The test accuracy is : -1.3836824094308637
#
#
# At random state39, The training accuracy is : 0.9837628424204642
# At random state39, The test accuracy is : 0.595371145853087
#
#
# At random state40, The training accuracy is : 0.9897331450924868
# At random state40, The test accuracy is : 0.27394932517308257
#
#
# At random state41, The training accuracy is : 0.9923413316898176
# At random state41, The test accuracy is : -0.8016107762245253
#
#
# At random state42, The training accuracy is : 0.9992558728325621
# At random state42, The test accuracy is : -0.38456281380507984
#
#
# At random state43, The training accuracy is : 0.9919418267881147
# At random state43, The test accuracy is : -2.930278142717526
#
#
# At random state44, The training accuracy is : 0.9871138977309001
# At random state44, The test accuracy is : 0.33547403599796666
#
#
# At random state45, The training accuracy is : 0.9922083276581848
# At random state45, The test accuracy is : -0.4572906606127616
#
#
# At random state46, The training accuracy is : 0.9892950295522662
# At random state46, The test accuracy is : -3.875532018837001
#
#
# At random state47, The training accuracy is : 0.9985300158935464
# At random state47, The test accuracy is : -2.1025522508474306
#
#
# At random state48, The training accuracy is : 0.9970920099821285
# At random state48, The test accuracy is : -1.5555319139075472
#
#
# At random state49, The training accuracy is : 0.9835007864077304
# At random state49, The test accuracy is : 0.6395263521906405
#
#
# At random state50, The training accuracy is : 0.9980818459117573
# At random state50, The test accuracy is : -0.04359257230847735
#
#
# At random state51, The training accuracy is : 0.9986147437482567
# At random state51, The test accuracy is : -1.4881141281498937
#
#
# At random state52, The training accuracy is : 0.9944327996990181
# At random state52, The test accuracy is : -0.041144871148754314
#
#
# At random state53, The training accuracy is : 0.9870019539425938
# At random state53, The test accuracy is : 0.36933997391906104
#
#
# At random state54, The training accuracy is : 0.9868456776714518
# At random state54, The test accuracy is : -1.3357855383442465
#
#
# At random state55, The training accuracy is : 0.991344484306979
# At random state55, The test accuracy is : -0.3801136882478797
#
#
# At random state56, The training accuracy is : 0.9989611350273166
# At random state56, The test accuracy is : -4.301046971627934
#
#
# At random state57, The training accuracy is : 0.9891293919561721
# At random state57, The test accuracy is : 0.7000059912075207
#
#
# At random state58, The training accuracy is : 0.9950715325442562
# At random state58, The test accuracy is : -0.2720804328515134
#
#
# At random state59, The training accuracy is : 0.9799251103288995
# At random state59, The test accuracy is : 0.799732136872173
#
#
# At random state60, The training accuracy is : 0.9990425011574048
# At random state60, The test accuracy is : -0.8394982750564222
#
#
# At random state61, The training accuracy is : 0.9946390819454347
# At random state61, The test accuracy is : 0.42471235220013803
#
#
# At random state62, The training accuracy is : 0.9867525722598318
# At random state62, The test accuracy is : 0.8329254131682536
#
#
# At random state63, The training accuracy is : 0.9985471932833252
# At random state63, The test accuracy is : -2.9172724566584596
#
#
# At random state64, The training accuracy is : 0.9961015357576442
# At random state64, The test accuracy is : 0.5824191374045278
#
#
# At random state65, The training accuracy is : 0.9936417300495601
# At random state65, The test accuracy is : 0.15771322623632966
#
#
# At random state66, The training accuracy is : 0.9798122544818098
# At random state66, The test accuracy is : -151.09580785541127
#
#
# At random state67, The training accuracy is : 0.9745148537549414
# At random state67, The test accuracy is : 0.28763856122622855
#
#
# At random state68, The training accuracy is : 0.9893382597939359
# At random state68, The test accuracy is : -0.20473144162325885
#
#
# At random state69, The training accuracy is : 0.9955760643757023
# At random state69, The test accuracy is : -0.20089161024438296
#
#
# At random state70, The training accuracy is : 0.9875781141676114
# At random state70, The test accuracy is : 0.23610528149784205
#
#
# At random state71, The training accuracy is : 0.996775924157053
# At random state71, The test accuracy is : -0.08590756530839272
#
#
# At random state72, The training accuracy is : 0.9822891092494359
# At random state72, The test accuracy is : -2.737246466550289
#
#
# At random state73, The training accuracy is : 0.9956685912668978
# At random state73, The test accuracy is : -1.5164911364794595
#
#
# At random state74, The training accuracy is : 0.9999124471699287
# At random state74, The test accuracy is : 0.08109045311668883
#
#
# At random state75, The training accuracy is : 0.9990229716332474
# At random state75, The test accuracy is : -4.560913115113247
# At random state76, The training accuracy is : 0.9652566878780464
# At random state76, The test accuracy is : 0.6844638020472569
#
#
# At random state77, The training accuracy is : 0.9988388389691216
# At random state77, The test accuracy is : -0.49097384142087797
#
#
# At random state78, The training accuracy is : 0.9686100408901416
# At random state78, The test accuracy is : 0.24612882650355905
#
#
# At random state79, The training accuracy is : 0.993522462847586
# At random state79, The test accuracy is : -0.37330726710646367
#
#
# At random state80, The training accuracy is : 0.9989810461097335
# At random state80, The test accuracy is : -0.9026800811861455
#
#
# At random state81, The training accuracy is : 0.9939820779208779
# At random state81, The test accuracy is : -0.5297694324059519
#
#
# At random state82, The training accuracy is : 0.9979693683707853
# At random state82, The test accuracy is : 0.24333114784976206
#
#
# At random state83, The training accuracy is : 0.982995930436959
# At random state83, The test accuracy is : 0.2682246775752589
#
#
# At random state84, The training accuracy is : 0.996005543206142
# At random state84, The test accuracy is : -1.4038908672367731
#
#
# At random state85, The training accuracy is : 0.9824972801467643
# At random state85, The test accuracy is : -0.9314147956062988
#
#
# At random state86, The training accuracy is : 0.99542814674678
# At random state86, The test accuracy is : -19.379461553388712
#
#
# At random state87, The training accuracy is : 0.9908857873631965
# At random state87, The test accuracy is : -0.20756074535982272
#
#
# At random state88, The training accuracy is : 0.9985987517500192
# At random state88, The test accuracy is : -0.07311114330731416
#
#
# At random state89, The training accuracy is : 0.9790186814212267
# At random state89, The test accuracy is : -0.7867406785447257
#
#
# At random state90, The training accuracy is : 0.992311613154328
# At random state90, The test accuracy is : -4.40290812255307
#
#
# At random state91, The training accuracy is : 0.9968549552023354
# At random state91, The test accuracy is : 0.5454916666095904
#
#
# At random state92, The training accuracy is : 0.9981532393775149
# At random state92, The test accuracy is : 0.37115560500565825
#
#
# At random state93, The training accuracy is : 0.9876614535970478
# At random state93, The test accuracy is : -6.018115569457222
#
#
# At random state94, The training accuracy is : 0.9939839735716851
# At random state94, The test accuracy is : -0.892679607108843
#
#
# At random state95, The training accuracy is : 0.9806646272345683
# At random state95, The test accuracy is : -0.7091606459623938
#
#
# At random state96, The training accuracy is : 0.9931015145003786
# At random state96, The test accuracy is : 0.2736721849761924
#
#
# At random state97, The training accuracy is : 0.9767961139919299
# At random state97, The test accuracy is : -0.28253216280451987
#
#
# At random state98, The training accuracy is : 0.9980750611413715
# At random state98, The test accuracy is : 0.4468061941113052
#
#
# At random state99, The training accuracy is : 0.9893157623650959
# At random state99, The test accuracy is : 0.6873768886012332

# %% [markdown]
# AS WE CONCLUDE THAT 22 STATE GAVE HIGHEST VALUE, SO TAKE 22 AS RANDOM STATE

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=22)

# %%
x_train.shape
# Out:
# (19, 16)

# %%
y_train.shape
# Out:
# (19,)

# %%
x_test.shape
# Out:
# (10, 16)

# %%
y_test.shape
# Out:
# (10,)

# %% [markdown]
# # MODEL BUILDING

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor

# %% [markdown]
# # 1.) LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train, y_train)
pred=lr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 3.7655525856830394
# Mean squared error : 18.5009808284413
# Root Mean squared error : 4.30127665100041
#  R2 Score :
# 84.02333261792634

# %%
score=cross_val_score(lr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',lr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : 0.037628660496460964
# Difference in R2 & CV Score: 80.26046656828025

# %% [markdown]
# # 2.)  SGD:

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 4.468155528679686e+16
# Mean squared error : 1.9981085025994316e+33
# Root Mean squared error : 4.470020696372033e+16
#  R2 Score :
# -1.725482299308663e+33

# %%
score=cross_val_score(sgd,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',sgd,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : SGDRegressor() :
#
# Mean CV Score : -1.9886438212639115e+30
# Difference in R2 & CV Score: -1.5266179171822718e+33

# %% [markdown]
# # 3.) RANDOM FOREST REGRESSION

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred=rfr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 5.708
# Mean squared error : 52.16955999999999
# Root Mean squared error : 7.2228498530704615
#  R2 Score :
# 54.9485664939551

# %%
score=cross_val_score(rfr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',rfr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : -0.8573053603229572
# Difference in R2 & CV Score: 140.6791025262508

# %% [markdown]
# # 4.)DECISION TREE REGRESSION

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 8.7
# Mean squared error : 85.7
# Root Mean squared error : 9.257429448826494
#  R2 Score :
# 25.993091537132983

# %%
score=cross_val_score(dtr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',dtr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : -2.529029297285984
# Difference in R2 & CV Score: 278.8960212657314

# %% [markdown]
# # 5.) EXTRA TREE REGRESSION

# %%
etc=ExtraTreesRegressor()
etc.fit(x_train,y_train)
pred=etc.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 5.982000000000001
# Mean squared error : 60.065020000000004
# Root Mean squared error : 7.750162578939877
#  R2 Score :
# 48.13037996545768

# %%
score=cross_val_score(etc,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',etc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : -0.6319155111554038
# Difference in R2 & CV Score: 111.32193108099806

# %% [markdown]
# # 6.)XGBOOST REGRESSION

# %%
xg=XGBRegressor()
xg.fit(x_train,y_train)
pred=xg.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 5.152705383300781
# Mean squared error : 39.79183550414164
# Root Mean squared error : 6.308077005248243
#  R2 Score :
# 65.63744775117303

# %%
score=cross_val_score(xg,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',xg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None) :
#
# Mean CV Score : -1.2138467823560102
# Difference in R2 & CV Score: 187.02212598677403

# %% [markdown]
# # HYPER PARAMETER TUNING: GRIDSEARCHCV

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'fit_intercept': [True, False],
              'normalize': [True, False]}

GCV = GridSearchCV(LinearRegression(),param_grid,cv =5)
GCV.fit(x_train,y_train)

best_model = GCV.best_estimator_
best_params = GCV.best_params_

pred = best_model.predict(x_test)

# %%
best_params
# Out:
# {'fit_intercept': True, 'normalize': False}

# %%
final_mod=LinearRegression(fit_intercept = True,normalize = False) 
final_mod.fit(x_train,y_train)
predict=final_mod.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2_Score: 84.02333261792634
# mean_squared_error: 18.5009808284413
# mean_absolute_error: 3.7655525856830394
# RMSE value: 4.30127665100041

# %% [markdown]
# AFTER TUNNIG I GOT 84% WHICH IS GOOD

# %% [markdown]
# # SAVING MODEL

# %%
import joblib
joblib.dump(final_mod,"BaseballCaseStudy.pkl")
# Out:
# ['BaseballCaseStudy.pkl']

# %% [markdown]
# # PREDICTION

# %%
model=joblib.load("BaseballCaseStudy.pkl")

#perdiction
prediction=model.predict(x_test)
prediction
# Out:
# array([89.51306452, 55.54711172, 83.93659969, 85.41450457, 62.94809171,
#        60.34962662, 74.81953404, 82.17272695, 65.71802147, 97.65353041])

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1        2          3          4          5  \
# Predicted  89.513065  55.547112  83.9366  85.414505  62.948092  60.349627
# Original   84.000000  63.000000  79.0000  83.000000  68.000000  64.000000
#
#                    6          7          8         9
# Predicted  74.819534  82.172727  65.718021  97.65353
# Original   76.000000  87.000000  68.000000  98.00000

# %% [markdown]
# # COMPLETED THE BASEBALLCASE STUDY
